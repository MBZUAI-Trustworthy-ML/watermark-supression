# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# Set larger font sizes globally
matplotlib.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'legend.fontsize': 12,
    'figure.titlesize': 18
})

# Data
query_counts = np.array([10, 100, 200, 1000, 2000, 5000, 10000])
success_rates = np.array([0.01, 0.07, x, 0.40, 0.77, 0.90, 0.96])
success_rates_ii = np.array([0.00, 0.04, x, 0.35, 0.72, 0.85, 0.91])

# Create the plot
fig, ax = plt.subplots(figsize=(6,6))

# Plot main line with markers and labels for legend
line1 = ax.plot(query_counts, success_rates, marker='o', linestyle='-', linewidth=2.5,
        color='red', label='Model Access', markersize=10)
line2 = ax.plot(query_counts, success_rates_ii, marker='o', linestyle='--', linewidth=2.5,
        color='black', label='Surrogate Model', markersize=10)

# Add grid lines
ax.grid(True, linestyle='--', alpha=0.7)

# Set x-axis to log scale
ax.set_xscale('log')

# Set axis labels
ax.set_xlabel('Number of Training Samples', fontweight='bold')
ax.set_ylabel('Spoofing Success Rate (FPR@1e-2)', fontweight='bold')
ax.set_ylim([0, 1.05])

# Add legend with proper positioning and formatting
ax.legend(loc='lower right', frameon=True, framealpha=0.9, edgecolor='lightgray')

# Remove the top and right spines to match your algorithm plots
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 1], pad=1.5, w_pad=1.0)

# Save figure
plt.savefig('query_count_vs_success_rate.pdf', bbox_inches='tight')

print("Plot created and saved with proper legends!")
# Out:
# Plot created and saved with proper legends!
