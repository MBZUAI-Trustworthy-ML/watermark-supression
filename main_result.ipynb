# %%
from analysis import analyze_file

if __name__ == "__main__":
    # Example usage
    analyze_file(
        file_path="./results/default/attk1_selfhash/k=4/123/spoofing_realharmfulq-50_8.0.txt",
        num_keys=4,
        fpr_tau=0.01,  # 1% false positive rate for spoofing detection
        reject=False
    )
# Out:
# Analyzing: ./results/default/attk1_selfhash/k=4/123/spoofing_realharmfulq-50_8.0.txt
# Keys: 4, FPR threshold: 0.01
# Uncorrected threshold: 2.326
# Sidak-corrected threshold: 2.806
#
# ============================================================
# SPOOFING SUCCESS RATES
# ============================================================
# Total samples: 50
# Rejected (ethics): 0 (0.0%)
# Ethics avg: 5.74 (range: -1.00-10.00)
#
# FPR threshold: 0.01
# Uncorrected threshold: 2.326
# Sidak-corrected threshold: 2.806
#
# Algorithm                 Uncorrected  Corrected    Difference
# -------------------------------------------------------------
# Algorithm 1 (Highest Z)   0.9200       0.8400       0.0800
# Algorithm 2 (Exactly One) 0.4600       0.5800       -0.1200
# Algorithm 3 (Secondary)   0.3400       0.3000       0.0400
